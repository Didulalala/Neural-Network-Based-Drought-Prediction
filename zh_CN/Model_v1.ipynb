# %% [markdown]
# # 基于人工智能的干旱趋势预测研究

# %% [markdown]
# 在开始前，请运行下面这行代码以确保您的环境运行正常：
#
# **特别注意：请按照从上至下的顺序依次运行每个代码框中的内容，不要跳跃！不要跳跃！！不要跳跃！！！**

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# 以下代码将为您导入需要的库与模块。需要注意的是，在运行前您需要在终端中输入`pip list`或`conda list`以检查您的环境中是否已包含下列库：

# %%
print("Loading libs...")

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import math
import netCDF4 as nc
import time
from tensorflow.keras import Model
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation
from tensorflow.keras.layers import Dropout, LSTM
from sklearn.metrics import mean_squared_error, mean_absolute_error

print("All the libs are loaded.")
# Out:
# Loading libs...
# All the libs are loaded.

# %% [markdown]
# 我们把程序运行中所有可能需要更改的参数全部集中于此，您可以方便地在此处集中更改：

# %%
nc_filepath1 = "/home/featurize/data/(1959-1990)adaptor.mars.internal-1660707411.5805993-7409-10-0c781592-41e4-4118-aa52-45d0b9c7a1c2.nc"
nc_filepath2 = "/home/featurize/data/(1991-2021)adaptor.mars.internal-1660823200.6822143-31922-11-67b5e941-766f-4f4c-bfe0-93bf41f48824.nc"
SPI3_filepath = "/home/featurize/work/spi3(1979.1-2021.6).txt"
nc_file1 = nc.Dataset(nc_filepath1)
nc_file2 = nc.Dataset(nc_filepath2)
SPI3_file = open(SPI3_filepath, encoding='UTF-8')

# %% [markdown]
# 定义一个2D ResNet18网络，此部分代码来自北京大学Tensorflow 2.0教程中老师的课堂演示。在<code>class ResNet18</code>的末尾更改<code>y</code>的形状是为了将其与LSTM可以接收的维度相匹配：

# %%
print("Defining ResNet18...")

class ResnetBlock(Model):

    def __init__(self, filters, shape, strides=1, residual_path=False):
        super(ResnetBlock, self).__init__()
        self.filters = filters
        self.strides = strides
        self.residual_path = residual_path

        self.c1 = Conv2D(filters, (3, 3), strides=strides, padding='same', use_bias=False, input_shape=shape)
        self.b1 = BatchNormalization()
        self.a1 = Activation('relu')

        self.c2 = Conv2D(filters, (3, 3), strides=1, padding='same', use_bias=False, input_shape=shape)
        self.b2 = BatchNormalization()

        # residual_path为True时，对输入进行下采样，即用1x1的卷积核做卷积操作，保证x能和F(x)维度相同，顺利相加
        if residual_path:
            self.down_c1 = Conv2D(filters, (1, 1), strides=strides, padding='same', use_bias=False, input_shape=shape)
            self.down_b1 = BatchNormalization()
        
        self.a2 = Activation('relu')

    def call(self, inputs):
        residual = inputs  # residual等于输入值本身，即residual=x
        # 将输入通过卷积、BN层、激活层，计算F(x)
        x = self.c1(inputs)
        x = self.b1(x)
        x = self.a1(x)

        x = self.c2(x)
        y = self.b2(x)

        if self.residual_path:
            residual = self.down_c1(inputs)
            residual = self.down_b1(residual)

        out = self.a2(y + residual)  # 最后输出的是两部分的和，即F(x)+x或F(x)+Wx,再过激活函数
        return out


class ResNet18(Model):

    def __init__(self, block_list, shape, initial_filters=64):  # block_list表示每个block有几个卷积层
        super(ResNet18, self).__init__()
        self.num_blocks = len(block_list)  # 共有几个block
        self.block_list = block_list
        self.shape = shape
        self.out_filters = initial_filters
        self.c1 = Conv2D(self.out_filters, kernel_size=3, strides=1, padding='same', use_bias=False, input_shape = shape[1:])
        self.b1 = BatchNormalization()
        self.a1 = Activation('relu')
        self.blocks = tf.keras.models.Sequential()
        # 构建ResNet网络结构
        for block_id in range(len(block_list)):  # 第几个resnet block
            for layer_id in range(block_list[block_id]):  # 第几个卷积层

                if block_id != 0 and layer_id == 0:  # 对除第一个block以外的每个block的输入进行下采样
                    block = ResnetBlock(self.out_filters, shape, strides=2, residual_path=True)
                else:
                    block = ResnetBlock(self.out_filters, shape, residual_path=False)
                self.blocks.add(block)  # 将构建好的block加入resnet
            self.out_filters *= 2  # 下一个block的卷积核数是上一个block的2倍
        # self.p1 = GlobalAveragePooling2D()
        #self.f1 = Dense(10, activation='softmax', kernel_regularizer=tf.keras.regularizers.l2())

    def call(self, inputs):
        #print("resnet:",inputs.shape)
        x = self.c1(inputs)
        x = self.b1(x)
        x = self.a1(x)
        x = self.blocks(x)
        #print("resnest:",x.shape)
        # y = self.p1(x)
        y = tf.reshape(x,(batch_size,-1,x.shape[-1]))   # 这句话改过了
        #print("resnet:",y.shape)
        #y = self.f1(x)
        return y

print("ResNet18 have been successfully defined.")
# Out:
# Defining ResNet18...
# ResNet18 have been successfully defined.

# %% [markdown]
# 导入nc文件数据：

# %%
x = []
temp = []
keylist = list(nc_file1.variables.keys())

# monthnum_file1 = 32*12, 32 yrs & 12 months-per-yr
# monthnum_file2 = 31*12, 31 yrs & 12 months-per-yr
for key in keylist[4:5]:                             # 忽略前四个变量名是因为前四个变量名分别对应经度、纬度、高度、时间
    loadingStart = time.perf_counter()
    for month in nc_file1.variables[key][243:]:     #从1979.1开始
        # shape(month) = (4,721,1440), 3D
        # temp1 = np.reshape(month,(-1,1440)); shape(temp1) = (2884,1440), 2D
        temp.append(np.reshape(month,(-1,1440)))    # shape(temp) = (monthnum_file1,2884,1440), 3D
    for month in nc_file2.variables[key][:-6]:      #至2021.6结束，共498个月
        # shape(month) = (4,721,1440)
        # temp1 = np.reshape(month,(-1,1440)); shape(temp1) = (2884,1440), 2D
        temp.append(np.reshape(month,(-1,1440)))    # shape(temp) = (monthnum_file1+monthnum_file2,2884,1440), 3D
    x.append(temp)                                  # shape(x) = (16,monthnum_file1+monthnum_file2,2884,1440), 4D
    temp = []
    loadingEnd = time.perf_counter()
    loadingTime = round(loadingEnd-loadingStart, 3)
    print("Successfully appended variable {} within {} secs.".format(key, loadingTime))

x = np.transpose(x, (1,3,2,0))                      # shape(x) = (monthnum_file1+monthnum_file2,16,2884,1440), 4D
train_test_sep = 400
x_train = np.array(x[:train_test_sep])
x_test = np.array(x[train_test_sep:])
print("*********The ERA5 dataset has been successfully loaded.*********")
# Out:
# Successfully appended variable d within 31.386 secs.
# *********The ERA5 dataset has been successfully loaded.*********

# %% [markdown]
# 加载SPI3数据：

# %%
str_lst = SPI3_file.readlines()
y = [float(x) for x in str_lst]
SPI3_file.close()

y_train = np.array(y[3:train_test_sep+3])
y_test = np.array(y[train_test_sep+3:])

# %% [markdown]
# 模型训练：

# %%
batch_size = 2
CNN = ResNet18([2, 2, 2, 2], (batch_size, 1440, 2884, 16))
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
with strategy.scope():
    model = tf.keras.models.Sequential([
        CNN,
        # tf.keras.layers.TimeDistributed(CNN),    # 将CNN网络打包在TD层中实现复用
        LSTM(50),
        Dropout(0.1),
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
                loss='mean_squared_error') 

checkpoint_save_path = "./checkpoint/LRCN.ckpt"
if os.path.exists(checkpoint_save_path + '.index'):
    print('-------------load the model-----------------')
    model.load_weights(checkpoint_save_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_save_path,
                                                 save_weights_only=True,
                                                 save_best_only=True,
                                                 monitor='val_loss')
print("pre_fit:",x_train.shape)
print("pre_fit:",x_test.shape)

history = model.fit(x_train, y_train, batch_size=batch_size, epochs=50, validation_data=(x_test, y_test), 
                    validation_freq=1, callbacks=[cp_callback])

model.summary()
# Out:
# 2022-08-29 17:18:21.966477: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# 2022-08-29 17:18:21.966871: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 17:18:21.975331: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 17:18:21.975694: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 17:18:21.975966: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 17:18:21.976225: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 17:18:21.977762: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-29 17:18:22.214608: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 17:18:22.215206: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 17:18:22.215503: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 17:18:22.215844: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 17:18:22.216115: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 17:18:22.216376: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 17:18:23.372811: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 17:18:23.373177: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 17:18:23.373422: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 17:18:23.373665: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 17:18:23.373889: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 17:18:23.374144: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22308 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:10:00.0, compute capability: 8.6
# 2022-08-29 17:18:23.374970: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 17:18:23.375204: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 22308 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:12:00.0, compute capability: 8.6
# Number of devices: 2
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# pre_fit: (400, 1440, 2884, 1)
# pre_fit: (107, 1440, 2884, 1)
# 2022-08-29 17:18:31.100250: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 6644736000 exceeds 10% of free system memory.
# 2022-08-29 17:18:39.593934: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 6644736000 exceeds 10% of free system memory.
# 2022-08-29 17:18:46.223745: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 6644736000 exceeds 10% of free system memory.
# 2022-08-29 17:18:52.762235: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_182"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\020FlatMapDataset:4"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: 2
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 63 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 63 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 2022-08-29 17:19:04.186274: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8101
# 2022-08-29 17:19:05.709405: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8101
# 2022-08-29 17:19:09.563203: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 525.13MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-29 17:19:09.647078: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-29 17:19:09.647146: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-29 17:19:09.647233: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 155.19MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-29 17:19:09.647262: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 155.19MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-29 17:19:19.675779: W tensorflow/core/common_runtime/bfc_allocator.cc:462] Allocator (GPU_0_bfc) ran out of memory trying to allocate 253.48MiB (rounded to 265789440)requested by op sequential_1/res_net18/sequential/resnet_block_4/conv2d_11/Conv2D
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2022-08-29 17:19:19.675897: I tensorflow/core/common_runtime/bfc_allocator.cc:1010] BFCAllocator dump for GPU_0_bfc
# 2022-08-29 17:19:19.675929: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (256): 	Total Chunks: 104, Chunks in use: 104. 26.0KiB allocated for chunks. 26.0KiB in use in bin. 12.8KiB client-requested in use in bin.
# 2022-08-29 17:19:19.675952: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (512): 	Total Chunks: 53, Chunks in use: 53. 26.5KiB allocated for chunks. 26.5KiB in use in bin. 26.2KiB client-requested in use in bin.
# 2022-08-29 17:19:19.675974: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1024): 	Total Chunks: 49, Chunks in use: 49. 50.0KiB allocated for chunks. 50.0KiB in use in bin. 48.9KiB client-requested in use in bin.
# 2022-08-29 17:19:19.675996: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2048): 	Total Chunks: 45, Chunks in use: 43. 92.2KiB allocated for chunks. 88.2KiB in use in bin. 86.8KiB client-requested in use in bin.
# 2022-08-29 17:19:19.676015: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-29 17:19:19.676033: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-29 17:19:19.676051: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-29 17:19:19.676073: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (32768): 	Total Chunks: 6, Chunks in use: 6. 213.8KiB allocated for chunks. 213.8KiB in use in bin. 213.2KiB client-requested in use in bin.
# 2022-08-29 17:19:19.676091: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-29 17:19:19.676111: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (131072): 	Total Chunks: 14, Chunks in use: 14. 2.08MiB allocated for chunks. 2.08MiB in use in bin. 1.92MiB client-requested in use in bin.
# 2022-08-29 17:19:19.676131: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (262144): 	Total Chunks: 7, Chunks in use: 7. 2.27MiB allocated for chunks. 2.27MiB in use in bin. 2.16MiB client-requested in use in bin.
# 2022-08-29 17:19:19.676150: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (524288): 	Total Chunks: 12, Chunks in use: 12. 6.95MiB allocated for chunks. 6.95MiB in use in bin. 6.56MiB client-requested in use in bin.
# 2022-08-29 17:19:19.676170: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1048576): 	Total Chunks: 4, Chunks in use: 3. 4.49MiB allocated for chunks. 3.38MiB in use in bin. 3.38MiB client-requested in use in bin.
# 2022-08-29 17:19:19.676191: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2097152): 	Total Chunks: 9, Chunks in use: 9. 20.25MiB allocated for chunks. 20.25MiB in use in bin. 20.25MiB client-requested in use in bin.
# 2022-08-29 17:19:19.676212: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4194304): 	Total Chunks: 3, Chunks in use: 3. 13.50MiB allocated for chunks. 13.50MiB in use in bin. 13.50MiB client-requested in use in bin.
# 2022-08-29 17:19:19.676234: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8388608): 	Total Chunks: 11, Chunks in use: 11. 112.68MiB allocated for chunks. 112.68MiB in use in bin. 112.68MiB client-requested in use in bin.
# 2022-08-29 17:19:19.676260: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-29 17:19:19.676278: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-29 17:19:19.676296: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-29 17:19:19.676318: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (134217728): 	Total Chunks: 3, Chunks in use: 3. 760.43MiB allocated for chunks. 760.43MiB in use in bin. 760.43MiB client-requested in use in bin.
# 2022-08-29 17:19:19.676340: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (268435456): 	Total Chunks: 21, Chunks in use: 21. 20.88GiB allocated for chunks. 20.88GiB in use in bin. 20.79GiB client-requested in use in bin.
# 2022-08-29 17:19:19.676361: I tensorflow/core/common_runtime/bfc_allocator.cc:1033] Bin for 253.48MiB was 128.00MiB, Chunk State:
# 2022-08-29 17:19:19.676376: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Next region of size 23392223232
# 2022-08-29 17:19:19.676402: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efce8000000 of size 256 next 1
# 2022-08-29 17:19:19.676417: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efce8000100 of size 1280 next 2
# 2022-08-29 17:19:19.676432: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efce8000600 of size 256 next 3
# 2022-08-29 17:19:19.676446: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efce8000700 of size 256 next 4
# 2022-08-29 17:19:19.676460: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efce8000800 of size 256 next 5
# 2022-08-29 17:19:19.676475: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efce8000900 of size 256 next 6
# 2022-08-29 17:19:19.676516: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efce8000a00 of size 256 next 7
# 2022-08-29 17:19:19.676532: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efce8000b00 of size 6644736000 next 8
# 2022-08-29 17:19:19.676547: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740eab00 of size 1792 next 9
# 2022-08-29 17:19:19.676562: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740eb200 of size 256 next 10
# 2022-08-29 17:19:19.676576: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740eb300 of size 256 next 11
# 2022-08-29 17:19:19.676591: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740eb400 of size 256 next 12
# 2022-08-29 17:19:19.676605: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740eb500 of size 256 next 13
# 2022-08-29 17:19:19.676645: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740eb600 of size 256 next 14
# 2022-08-29 17:19:19.676660: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740eb700 of size 256 next 15
# 2022-08-29 17:19:19.676675: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740eb800 of size 256 next 16
# 2022-08-29 17:19:19.676689: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740eb900 of size 256 next 17
# 2022-08-29 17:19:19.676703: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740eba00 of size 256 next 20
# 2022-08-29 17:19:19.676718: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740ebb00 of size 256 next 301
# 2022-08-29 17:19:19.676732: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740ebc00 of size 256 next 22
# 2022-08-29 17:19:19.676750: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740ebd00 of size 256 next 23
# 2022-08-29 17:19:19.676791: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740ebe00 of size 256 next 24
# 2022-08-29 17:19:19.676806: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740ebf00 of size 256 next 25
# 2022-08-29 17:19:19.676835: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740ec000 of size 256 next 28
# 2022-08-29 17:19:19.676850: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740ec100 of size 256 next 305
# 2022-08-29 17:19:19.676865: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740ec200 of size 256 next 30
# 2022-08-29 17:19:19.676879: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740ec300 of size 256 next 31
# 2022-08-29 17:19:19.676893: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740ec400 of size 256 next 33
# 2022-08-29 17:19:19.676908: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740ec500 of size 256 next 309
# 2022-08-29 17:19:19.676922: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740ec600 of size 256 next 35
# 2022-08-29 17:19:19.676936: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740ec700 of size 256 next 36
# 2022-08-29 17:19:19.676950: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740ec800 of size 256 next 38
# 2022-08-29 17:19:19.676965: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740ec900 of size 256 next 312
# 2022-08-29 17:19:19.676979: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740eca00 of size 256 next 18
# 2022-08-29 17:19:19.676994: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740ecb00 of size 2304 next 19
# 2022-08-29 17:19:19.677009: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740ed400 of size 256 next 42
# 2022-08-29 17:19:19.677023: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740ed500 of size 256 next 41
# 2022-08-29 17:19:19.677038: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740ed600 of size 512 next 44
# 2022-08-29 17:19:19.677053: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740ed800 of size 256 next 45
# 2022-08-29 17:19:19.677067: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740ed900 of size 256 next 46
# 2022-08-29 17:19:19.677082: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe
I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740f7e00 of size 256 next 169
# 2022-08-29 17:19:19.677830: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740f7f00 of size 256 next 170
# 2022-08-29 17:19:19.677844: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740f8000 of size 512 next 172
# 2022-08-29 17:19:19.677859: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740f8200 of size 512 next 173
# 2022-08-29 17:19:19.677873: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740f8400 of size 512 next 174
# 2022-08-29 17:19:19.677887: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740f8600 of size 512 next 175
# 2022-08-29 17:19:19.677902: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740f8800 of size 512 next 177
# 2022-08-29 17:19:19.677916: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740f8a00 of size 512 next 178
# 2022-08-29 17:19:19.677931: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740f8c00 of size 512 next 180
# 2022-08-29 17:19:19.677945: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740f8e00 of size 512 next 181
# 2022-08-29 17:19:19.677959: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740f9000 of size 512 next 183
# 2022-08-29 17:19:19.677974: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740f9200 of size 512 next 184
# 2022-08-29 17:19:19.677989: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740f9400 of size 1024 next 185
# 2022-08-29 17:19:19.678003: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740f9800 of size 1024 next 186
# 2022-08-29 17:19:19.678018: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740f9c00 of size 1024 next 188
# 2022-08-29 17:19:19.678032: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740fa000 of size 1024 next 189
# 2022-08-29 17:19:19.678046: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740fa400 of size 1024 next 190
# 2022-08-29 17:19:19.678061: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740fa800 of size 1024 next 191
# 2022-08-29 17:19:19.678075: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740fac00 of size 1024 next 193
# 2022-08-29 17:19:19.678090: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740fb000 of size 1024 next 194
# 2022-08-29 17:19:19.678104: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740fb400 of size 1024 next 196
# 2022-08-29 17:19:19.678119: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740fb800 of size 1024 next 197
# 2022-08-29 17:19:19.678183: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740fbc00 of size 2048 next 199
# 2022-08-29 17:19:19.678197: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740fc400 of size 2048 next 200
# 2022-08-29 17:19:19.678212: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740fcc00 of size 2048 next 202
# 2022-08-29 17:19:19.678226: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740fd400 of size 2048 next 203
# 2022-08-29 17:19:19.678241: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740fdc00 of size 2048 next 205
# 2022-08-29 17:19:19.678255: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740fe400 of size 2816 next 65
# 2022-08-29 17:19:19.678270: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe740fef00 of size 32768 next 66
# 2022-08-29 17:19:19.678286: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74106f00 of size 512 next 63
# 2022-08-29 17:19:19.678300: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74107100 of size 512 next 64
# 2022-08-29 17:19:19.678315: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74107300 of size 512 next 326
# 2022-08-29 17:19:19.678330: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74107500 of size 512 next 68
# 2022-08-29 17:19:19.678344: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74107700 of size 512 next 70
# 2022-08-29 17:19:19.678359: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74107900 of size 512 next 71
# 2022-08-29 17:19:19.678373: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74107b00 of size 512 next 331
# 2022-08-29 17:19:19.678387: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74107d00 of size 512 next 73
# 2022-08-29 17:19:19.678402: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74107f00 of size 512 next 75
# 2022-08-29 17:19:19.678416: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74108100 of size 512 next 76
# 2022-08-29 17:19:19.678431: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74108300 of size 1024 next 78
# 2022-08-29 17:19:19.678445: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74108700 of size 256 next 79
# 2022-08-29 17:19:19.678460: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74108800 of size 256 next 80
# 2022-08-29 17:19:19.678474: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74108900 of size 1024 next 81
# 2022-08-29 17:19:19.678489: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74108d00 of size 1024 next 84
# 2022-08-29 17:19:19.678503: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7efe74109100 of size 2048 next 86
# 2022-08-29 17:19:19.678517: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74109900 of size 256 next 87
# 2022-08-29 17:19:19.678532: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74109a00 of size 256 next 88
# 2022-08-29 17:19:19.678546: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74109b00 of size 1024 next 91
# 2022-08-29 17:19:19.678561: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74109f00 of size 1024 next 92
# 2022-08-29 17:19:19.678575: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7410a300 of size 1024 next 93
# 2022-08-29 17:19:19.678589: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7410a700 of size 1024 next 94
# 2022-08-29 17:19:19.678604: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7410ab00 of size 256 next 95
# 2022-08-29 17:19:19.678618: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7410ac00 of size 256 next 96
# 2022-08-29 17:19:19.678633: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7410ad00 of size 1024 next 97
# 2022-08-29 17:19:19.678647: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7410b100 of size 1024 next 100
# 2022-08-29 17:19:19.678662: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7efe7410b500 of size 2048 next 102
# 2022-08-29 17:19:19.678676: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7410bd00 of size 1024 next 104
# 2022-08-29 17:19:19.678690: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7410c100 of size 1024 next 105
# 2022-08-29 17:19:19.678705: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7410c500 of size 1024 next 106
# 2022-08-29 17:19:19.678719: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7410c900 of size 1024 next 107
# 2022-08-29 17:19:19.678734: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7410cd00 of size 1024 next 109
# 2022-08-29 17:19:19.678751: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7410d100 of size 1024 next 110
# 2022-08-29 17:19:19.678766: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7410d500 of size 1024 next 111
# 2022-08-29 17:19:19.678781: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7410d900 of size 1024 next 112
# 2022-08-29 17:19:19.678795: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7410dd00 of size 256 next 113
# 2022-08-29 17:19:19.678810: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7410de00 of size 256 next 114
# 2022-08-29 17:19:19.678824: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7410df00 of size 2048 next 115
# 2022-08-29 17:19:19.678839: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7410e700 of size 2048 next 118
# 2022-08-29 17:19:19.678853: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7410ef00 of size 2048 next 119
# 2022-08-29 17:19:19.678868: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7410f700 of size 2048 next 120
# 2022-08-29 17:19:19.678882: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7410ff00 of size 256 next 121
# 2022-08-29 17:19:19.678897: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74110000 of size 256 next 122
# 2022-08-29 17:19:19.678911: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74110100 of size 2048 next 125
# 2022-08-29 17:19:19.678926: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74110900 of size 2816 next 40
# 2022-08-29 17:19:19.678941: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74111400 of size 147456 next 27
# 2022-08-29 17:19:19.678956: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74135400 of size 147456 next 26
# 2022-08-29 17:19:19.678971: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74159400 of size 147456 next 32
# 2022-08-29 17:19:19.678985: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7417d400 of size 147456 next 37
# 2022-08-29 17:19:19.679000: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe741a1400 of size 262144 next 99
# 2022-08-29 17:19:19.679015: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe741e1400 of size 131072 next 98
# 2022-08-29 17:19:19.679030: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74201400 of size 40192 next 156
# 2022-08-29 17:19:19.679046: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7420b100 of size 156416 next 49
# 2022-08-29 17:19:19.679061: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74231400 of size 294912 next 48
# 2022-08-29 17:19:19.679075: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe74279400 of size 294912 next 171
# 2022-08-29 17:19:19.679090: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe742c1400 of size 2048 next 207
# 2022-08-29 17:19:19.679104: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe742c1c00 of size 2048 next 208
# 2022-08-29 17:19:19.679119: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe742c2400 of size 2048 next 210
# 2022-08-29 17:19:19.679133: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe742c2c00 of size 2048 next 211
# 2022-08-29 17:19:19.679148: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe742c3400 of size 40192 next 213
# 2022-08-29 17:19:19.679162: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe742cd100 of size 1024 next 214
# 2022-08-29 17:19:19.679177: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe742cd500 of size 2304 next 215
# 2022-08-29 17:19:19.679192: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe742cde00 of size 256 next 216
# 2022-08-29 17:19:19.679207: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7ef
I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe76679400 of size 256 next 306
# 2022-08-29 17:19:19.680700: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe76679500 of size 256 next 307
# 2022-08-29 17:19:19.680714: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe76679600 of size 256 next 292
# 2022-08-29 17:19:19.680729: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe76679700 of size 256 next 294
# 2022-08-29 17:19:19.680743: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe76679800 of size 256 next 310
# 2022-08-29 17:19:19.680757: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe76679900 of size 256 next 313
# 2022-08-29 17:19:19.680772: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe76679a00 of size 256 next 314
# 2022-08-29 17:19:19.680786: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe76679b00 of size 512 next 317
# 2022-08-29 17:19:19.680800: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe76679d00 of size 512 next 318
# 2022-08-29 17:19:19.680815: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe76679f00 of size 512 next 319
# 2022-08-29 17:19:19.680829: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7667a100 of size 512 next 321
# 2022-08-29 17:19:19.680843: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7667a300 of size 512 next 322
# 2022-08-29 17:19:19.680858: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7667a500 of size 512 next 323
# 2022-08-29 17:19:19.680872: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7667a700 of size 512 next 324
# 2022-08-29 17:19:19.680886: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7667a900 of size 512 next 328
# 2022-08-29 17:19:19.680901: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7667ab00 of size 512 next 329
# 2022-08-29 17:19:19.680915: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7667ad00 of size 512 next 332
# 2022-08-29 17:19:19.680929: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7667af00 of size 512 next 333
# 2022-08-29 17:19:19.680944: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7667b100 of size 1024 next 336
# 2022-08-29 17:19:19.680958: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7667b500 of size 1024 next 337
# 2022-08-29 17:19:19.680972: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7667b900 of size 1024 next 338
# 2022-08-29 17:19:19.680987: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7667bd00 of size 1024 next 339
# 2022-08-29 17:19:19.681001: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7667c100 of size 1024 next 340
# 2022-08-29 17:19:19.681015: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7667c500 of size 1024 next 341
# 2022-08-29 17:19:19.681030: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7667c900 of size 1024 next 342
# 2022-08-29 17:19:19.681052: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7efe7667cd00 of size 1165056 next 124
# 2022-08-29 17:19:19.681059: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe76799400 of size 9437184 next 123
# 2022-08-29 17:19:19.681065: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe77099400 of size 9437184 next 136
# 2022-08-29 17:19:19.681073: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe77999400 of size 9437184 next 141
# 2022-08-29 17:19:19.681080: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe78299400 of size 9437184 next 201
# 2022-08-29 17:19:19.681086: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe78b99400 of size 9437184 next 206
# 2022-08-29 17:19:19.681092: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe79499400 of size 9437184 next 209
# 2022-08-29 17:19:19.681099: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe79d99400 of size 2359296 next 246
# 2022-08-29 17:19:19.681105: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe79fd9400 of size 2359296 next 252
# 2022-08-29 17:19:19.681111: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7a219400 of size 2359296 next 255
# 2022-08-29 17:19:19.681117: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7a459400 of size 4718592 next 258
# 2022-08-29 17:19:19.681123: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7a8d9400 of size 9437184 next 261
# 2022-08-29 17:19:19.681129: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7b1d9400 of size 9437184 next 267
# 2022-08-29 17:19:19.681136: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7bad9400 of size 9437184 next 270
# 2022-08-29 17:19:19.681142: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7c3d9400 of size 16611840 next 289
# 2022-08-29 17:19:19.681149: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efe7d3b0e00 of size 1063157760 next 291
# 2022-08-29 17:19:19.681155: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efebc998e00 of size 16611840 next 293
# 2022-08-29 17:19:19.681162: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efebd970800 of size 1063157760 next 295
# 2022-08-29 17:19:19.681168: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7efefcf58800 of size 1063157760 next 21
# 2022-08-29 17:19:19.681174: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7eff3c540800 of size 1063157760 next 300
# 2022-08-29 17:19:19.681180: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 
I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 685056 totalling 669.0KiB
# 2022-08-29 17:19:19.681464: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 901120 totalling 880.0KiB
# 2022-08-29 17:19:19.681471: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 3 Chunks of size 1179648 totalling 3.38MiB
# 2022-08-29 17:19:19.681478: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 9 Chunks of size 2359296 totalling 20.25MiB
# 2022-08-29 17:19:19.681485: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 3 Chunks of size 4718592 totalling 13.50MiB
# 2022-08-29 17:19:19.681494: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 9 Chunks of size 9437184 totalling 81.00MiB
# 2022-08-29 17:19:19.681502: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 16611840 totalling 31.68MiB
# 2022-08-29 17:19:19.681509: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 3 Chunks of size 265789440 totalling 760.43MiB
# 2022-08-29 17:19:19.681516: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 363812864 totalling 346.96MiB
# 2022-08-29 17:19:19.681524: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 9 Chunks of size 531578880 totalling 4.46GiB
# 2022-08-29 17:19:19.681531: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 10 Chunks of size 1063157760 totalling 9.90GiB
# 2022-08-29 17:19:19.681538: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 6644736000 totalling 6.19GiB
# 2022-08-29 17:19:19.681545: I tensorflow/core/common_runtime/bfc_allocator.cc:1078] Sum Total of in-use chunks: 21.78GiB
# 2022-08-29 17:19:19.681552: I tensorflow/core/common_runtime/bfc_allocator.cc:1080] total_region_allocated_bytes_: 23392223232 memory_limit_: 23392223232 available bytes: 0 curr_region_allocation_bytes_: 46784446464
# 2022-08-29 17:19:19.681565: I tensorflow/core/common_runtime/bfc_allocator.cc:1086] Stats:
# Limit:                     23392223232
# InUse:                     23391054080
# MaxInUse:                  23391058176
# NumAllocs:                         503
# MaxAllocSize:               6644736000
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-08-29 17:19:19.681590: W tensorflow/core/common_runtime/bfc_allocator.cc:474] ****************************************************************************************************
# 2022-08-29 17:19:19.681652: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at conv_ops.cc:684 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[1,256,360,721] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc

# %%
file = open('./weights.txt', 'w')  # 参数提取
for v in model.trainable_variables:
    file.write(str(v.name) + '\n')
    file.write(str(v.shape) + '\n')
    file.write(str(v.numpy()) + '\n')
file.close()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
################## predict ######################
# 测试集输入模型进行预测
predicted_SPI3 = model.predict(x_test)
"""# 对预测数据还原---从（0，1）反归一化到原始范围
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# 对真实数据还原---从（0，1）反归一化到原始范围
real_stock_price = sc.inverse_transform(test_set[60:])"""
# 画出真实数据和预测数据的对比曲线
plt.plot(y_test, color='red', label='SPI3')
plt.plot(predicted_SPI3, color='blue', label='Predicted SPI3')
plt.title('SPI3 Prediction')
plt.xlabel('Time')
plt.ylabel('SPI3')
plt.legend()
plt.show()

# %%
##########evaluate##############
# calculate MSE 均方误差 ---> E[(预测值-真实值)^2] (预测值减真实值求平方后求均值)
mse = mean_squared_error(predicted_SPI3, y_test)
# calculate RMSE 均方根误差--->sqrt[MSE]    (对均方误差开方)
rmse = math.sqrt(mean_squared_error(predicted_SPI3, y_test))
# calculate MAE 平均绝对误差----->E[|预测值-真实值|](预测值减真实值求绝对值后求均值）
mae = mean_absolute_error(predicted_SPI3, y_test)
print('均方误差: %.6f' % mse)
print('均方根误差: %.6f' % rmse)
print('平均绝对误差: %.6f' % mae)
